# %%
import pandas as pd
import json
from pathlib import Path

BASE = Path(".")
STATIONS_JSON = BASE / "stations.json"
STOPS_FILE = BASE / "stops.txt"
STOP_TIMES_FILE = BASE / "stop_times.txt"
TRIPS_FILE = BASE / "trips.txt"
ROUTES_FILE = BASE / "routes.txt"

DEST_NAME_FOR_LINE = {
    "1": "Chambers St",
    "2": "Chambers St",
    "3": "Chambers St",
    "A": "Chambers St",
    "C": "Chambers St",
    "E": "World Trade Center",
}

# Morning commute window (for now)
MORNING_START_HOUR = 7   # 7:00
MORNING_END_HOUR = 11    # 11:59


def time_to_seconds(t_str: str):
    try:
        h, m, s = map(int, t_str.split(":"))
        return h * 3600 + m * 60 + s
    except Exception:
        return None

def is_morning(t_str: str) -> bool:
    sec = time_to_seconds(t_str)
    if sec is None:
        return False
    hour = sec // 3600
    return MORNING_START_HOUR <= hour < MORNING_END_HOUR

def main():
    print("Loading GTFS files...")
    stops = pd.read_csv(STOPS_FILE)
    stop_times = pd.read_csv(STOP_TIMES_FILE)
    trips = pd.read_csv(TRIPS_FILE)
    routes = pd.read_csv(ROUTES_FILE)
    trips_routes = trips.merge(routes[["route_id", "route_short_name"]],
                               on="route_id", how="left")
    trips_routes["line"] = trips_routes["route_short_name"].astype(str).str.strip()

    print("Loading stations.json...")
    with open(STATIONS_JSON, "r") as f:
        stations_data = json.load(f)
    stations = stations_data["stations"]

    print("Building origin station -> stop_id mapping...")

    station_to_stop_ids = {}
    for st in stations:
        name = st["Station Name"]
        mask = stops["stop_name"].str.contains(name, case=False, na=False)
        ids = stops.loc[mask, "stop_id"].unique().tolist()
        station_to_stop_ids[name] = ids


    print("Finding destination stop_ids...")
    line_to_dest_stop_ids = {}

    for line, dest_name in DEST_NAME_FOR_LINE.items():
        mask = stops["stop_name"].str.contains(dest_name, case=False, na=False)
        dest_ids = stops.loc[mask, "stop_id"].unique().tolist()
        if not dest_ids:
            print(f"WARNING: No destination stops found for line {line} with name '{dest_name}'")
        line_to_dest_stop_ids[line] = dest_ids

    
    print("Merging stop_times with trips...")
    st_with_trips = stop_times.merge(trips_routes[["trip_id", "route_id", "line"]],
                                     on="trip_id", how="left")

    st_by_stop = st_with_trips.set_index("stop_id")

    results = {}

    print("Computing travel times for each station & line...")
    for st in stations:
        station_name = st["Station Name"]
        lines = st["Train Lines"]
        origin_stop_ids = station_to_stop_ids.get(station_name, [])

        results[station_name] = {}

        if not origin_stop_ids:
            print(f"  [WARN] No stop_ids found for station '{station_name}'")
            for line in lines:
                results[station_name][line] = None
            continue

        for line in lines:
            dest_ids = line_to_dest_stop_ids.get(line, [])
            if not dest_ids:
                print(f"  [WARN] No destination ids for line {line}, station {station_name}")
                results[station_name][line] = None
                continue

            origin_rows = st_with_trips[
                (st_with_trips["stop_id"].isin(origin_stop_ids)) &
                (st_with_trips["line"] == line)
            ]
            dest_rows = st_with_trips[
                (st_with_trips["stop_id"].isin(dest_ids)) &
                (st_with_trips["line"] == line)
            ]

            if origin_rows.empty or dest_rows.empty:
                print(f"  [INFO] No matching trips for {station_name} on line {line}")
                results[station_name][line] = None
                continue

            merged = origin_rows.merge(
                dest_rows,
                on="trip_id",
                suffixes=("_orig", "_dest")
            )
            
            merged = merged[merged["stop_sequence_orig"] < merged["stop_sequence_dest"]]

            durations = []
            for _, row in merged.iterrows():
                dep = row["departure_time_orig"]
                arr = row["arrival_time_dest"]

                if not (isinstance(dep, str) and isinstance(arr, str)):
                    continue

                if not (is_morning(dep) and is_morning(arr)):
                    continue

                dep_s = time_to_seconds(dep)
                arr_s = time_to_seconds(arr)
                if dep_s is None or arr_s is None:
                    continue

                dt = arr_s - dep_s
                if 0 < dt < 3 * 3600:
                    durations.append(dt / 60.0)

            if durations:
                avg_minutes = round(sum(durations) / len(durations))
                results[station_name][line] = int(avg_minutes)
                print(f"  {station_name} ({line}): avg {avg_minutes} min, samples={len(durations)}")
            else:
                print(f"  [INFO] No valid durations for {station_name} on {line}")
                results[station_name][line] = None

    FALLBACK_MIN = 30
    final_output = {}
    for station_name, line_map in results.items():
        final_output[station_name] = {}
        for line, mins in line_map.items():
            if mins is None:
                final_output[station_name][line] = FALLBACK_MIN
            else:
                final_output[station_name][line] = mins

    out_path = BASE / "travel_times.json"
    with open(out_path, "w") as f:
        json.dump(final_output, f, indent=2)

    print(f"\nSaved travel_times.json to {out_path.resolve()}")


if __name__ == "__main__":
    main()
# Out:
# Loading GTFS files...
# Loading stations.json...
# Building origin station -> stop_id mapping...
# Finding destination stop_ids...
# Merging stop_times with trips...
# /var/folders/dy/xq75wbj1345d8bk_wpg5rl8r0000gn/T/ipykernel_26392/686833048.py:80: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask = stops["stop_name"].str.contains(name, case=False, na=False)
# Computing travel times for each station & line...
#   103 St (1): avg 26 min, samples=99
#   103 St (A): avg 22 min, samples=1
#   103 St (C): avg 24 min, samples=58
#   104 St (A): avg 33 min, samples=39
#   110 St-Malcolm X Plaza (2): avg 20 min, samples=82
#   110 St-Malcolm X Plaza (3): avg 20 min, samples=69
#   111 St (A): avg 34 min, samples=39
#   116 St (2): avg 21 min, samples=82
#   116 St (3): avg 21 min, samples=69
#   116 St (A): avg 57 min, samples=3
#   116 St (C): avg 26 min, samples=57
#   116 St-Columbia University (1): avg 28 min, samples=99
#   125 St (1): avg 31 min, samples=98
#   125 St (2): avg 23 min, samples=80
#   125 St (3): avg 23 min, samples=69
#   125 St (A): avg 21 min, samples=71
#   125 St (C): avg 28 min, samples=57
#   135 St (2): avg 24 min, samples=80
#   135 St (3): avg 24 min, samples=67
#   [INFO] No valid durations for 135 St on A
#   135 St (C): avg 30 min, samples=57
#   137 St-City College (1): avg 32 min, samples=97
#   14 St (1): avg 7 min, samples=105
#   14 St (2): avg 5 min, samples=88
#   14 St (3): avg 5 min, samples=72
#   14 St (A): avg 7 min, samples=76
#   14 St (C): avg 8 min, samples=60
#   14 St (E): avg 8 min, samples=83
#   145 St (1): avg 34 min, samples=90
#   145 St (3): avg 26 min, samples=67
#   145 St (A): avg 25 min, samples=71
#   145 St (C): avg 32 min, samples=56
#   149 St-Grand Concourse (2): avg 28 min, samples=79
#   [INFO] No valid durations for 155 St on A
#   155 St (C): avg 33 min, samples=56
#   157 St (1): avg 36 min, samples=90
#   [INFO] No valid durations for 163 St-Amsterdam Av on A
#   163 St-Amsterdam Av (C): avg 35 min, samples=55
#   168 St (A): avg 28 min, samples=69
#   168 St (C): avg 36 min, samples=54
#   168 St-Washington Hts (1): avg 37 min, samples=89
#   [INFO] No valid durations for 169 St on E
#   174 St (2): avg 41 min, samples=73
#   175 St (A): avg 30 min, samples=69
#   18 St (1): avg 8 min, samples=105
#   18 St (2): avg 8 min, samples=1
#   181 St (1): avg 39 min, samples=88
#   181 St (A): avg 32 min, samples=69
#   190 St (A): avg 34 min, samples=69
#   191 St (1): avg 41 min, samples=88
#   207 St (1): avg 44 min, samples=87
#   215 St (1): avg 45 min, samples=87
#   219 St (2): avg 55 min, samples=68
#   225 St (2): avg 56 min, samples=68
#   23 St (1): avg 9 min, samples=105
#   [INFO] No valid durations for 23 St on 2
#   23 St (A): avg 8 min, samples=2
#   23 St (C): avg 9 min, samples=60
#   23 St (E): avg 17 min, samples=160
#   231 St (1): avg 48 min, samples=85
#   233 St (2): avg 58 min, samples=68
#   238 St (1): avg 50 min, samples=85
#   28 St (1): avg 10 min, samples=105
#   [INFO] No valid durations for 28 St on 2
#   3 Av-149 St (2): avg 30 min, samples=79
#   34 St-Penn Station (1): avg 11 min, samples=104
#   34 St-Penn Station (2): avg 7 min, samples=85
#   34 St-Penn Station (3): avg 7 min, samples=72
#   34 St-Penn Station (A): avg 9 min, samples=75
#   34 St-Penn Station (C): avg 11 min, samples=60
#   34 St-Penn Station (E): avg 11 min, samples=82
#   [INFO] No valid durations for 36 St on E
#   42 St-Port Authority Bus Terminal (A): avg 10 min, samples=75
#   42 St-Port Authority Bus Terminal (C): avg 12 min, samples=60
#   42 St-Port Authority Bus Terminal (E): avg 12 min, samples=82
#   [INFO] No valid durations for 46 St on E
#   5 Av/53 St (E): avg 20 min, samples=80
#   50 St (1): avg 15 min, samples=102
#   [INFO] No valid durations for 50 St on 2
#   50 St (A): avg 13 min, samples=1
#   50 St (C): avg 14 min, samples=59
#   50 St (E): avg 14 min, samples=81
#   59 St-Columbus Circle (1): avg 17 min, samples=102
#   [INFO] No valid durations for 59 St-Columbus Circle on 2
#   59 St-Columbus Circle (A): avg 13 min, samples=74
#   59 St-Columbus Circle (C): avg 16 min, samples=58
#   [INFO] No valid durations for 63 Dr-Rego Park on E
#   [INFO] No valid durations for 65 St on E
#   66 St-Lincoln Center (1): avg 18 min, samples=102
#   [INFO] No valid durations for 66 St-Lincoln Center on 2
#   [INFO] No valid durations for 67 Av on E
#   7 Av (E): avg 18 min, samples=81
#   72 St (1): avg 20 min, samples=101
#   72 St (2): avg 13 min, samples=84
#   72 St (3): avg 13 min, samples=70
#   72 St (A): avg 16 min, samples=1
#   72 St (C): avg 18 min, samples=58
#   75 Av (E): avg 42 min, samples=32
#   79 St (1): avg 21 min, samples=101
#   [INFO] No valid durations for 79 St on 2
#   80 St (A): avg 28 min, samples=82
#   81 St-Museum of Natural History (A): avg 18 min, samples=1
#   81 St-Museum of Natural History (C): avg 19 min, samples=58
#   86 St (1): avg 22 min, samples=101
#   [INFO] No valid durations for 86 St on 2
#   86 St (A): avg 19 min, samples=1
#   86 St (C): avg 21 min, samples=58
#   88 St (A): avg 30 min, samples=82
#   96 St (1): avg 24 min, samples=100
#   96 St (2): avg 15 min, samples=83
#   96 St (3): avg 16 min, samples=70
#   96 St (A): avg 20 min, samples=1
#   96 St (C): avg 22 min, samples=58
#   Allerton Av (2): avg 51 min, samples=69
#   Aqueduct Racetrack (A): avg 35 min, samples=42
#   Aqueduct-N Conduit Av (A): avg 36 min, samples=42
#   Atlantic Av-Barclays Ctr (2): avg 14 min, samples=76
#   Atlantic Av-Barclays Ctr (3): avg 14 min, samples=60
#   Beach 105 St (A): avg 54 min, samples=4
#   Beach 25 St (A): avg 56 min, samples=34
#   Beach 36 St (A): avg 54 min, samples=34
#   Beach 44 St (A): avg 52 min, samples=34
#   Beach 60 St (A): avg 50 min, samples=34
#   Beach 67 St (A): avg 49 min, samples=34
#   Beach 90 St (A): avg 50 min, samples=4
#   Beach 98 St (A): avg 52 min, samples=4
#   Bergen St (2): avg 15 min, samples=76
#   Bergen St (3): avg 15 min, samples=60
#   Beverly Rd (2): avg 30 min, samples=70
#   Borough Hall (2): avg 9 min, samples=76
#   Borough Hall (3): avg 9 min, samples=61
#   Briarwood (E): avg 45 min, samples=30
#   Broad Channel (A): avg 45 min, samples=40
#   Broadway Junction (A): avg 20 min, samples=86
#   Broadway Junction (C): avg 23 min, samples=56
#   Bronx Park East (2): avg 47 min, samples=72
#   Burke Av (2): avg 52 min, samples=69
#   Canal St (1): avg 2 min, samples=107
#   Canal St (2): avg 2 min, samples=1
#   Canal St (A): avg 2 min, samples=78
#   Canal St (C): avg 2 min, samples=61
#   Canal St (E): avg 2 min, samples=85
#   [WARN] No stop_ids found for station 'Cathedral Pkwy (110 St)'
#   [INFO] No valid durations for Chambers St on 1
#   [INFO] No valid durations for Chambers St on 2
#   [INFO] No valid durations for Chambers St on 3
#   [INFO] No valid durations for Chambers St on A
#   [INFO] No valid durations for Chambers St on C
#   Christopher St-Stonewall (1): avg 6 min, samples=106
#   Christopher St-Stonewall (2): avg 6 min, samples=1
#   Church Av (2): avg 28 min, samples=71
#   Clark St (2): avg 8 min, samples=77
#   Clark St (3): avg 8 min, samples=62
#   Clinton-Washington Avs (A): avg 12 min, samples=1
#   Clinton-Washington Avs (C): avg 12 min, samples=59
#   Court Sq-23 St (E): avg 24 min, samples=78
#   Crown Hts-Utica Av (2): avg 28 min, samples=1
#   Crown Hts-Utica Av (3): avg 26 min, samples=58
#   Dyckman St (1): avg 42 min, samples=87
#   Dyckman St (A): avg 36 min, samples=68
#   E 180 St (2): avg 44 min, samples=73
#   Eastern Pkwy-Brooklyn Museum (2): avg 19 min, samples=73
#   Eastern Pkwy-Brooklyn Museum (3): avg 19 min, samples=60
#   [INFO] No valid durations for Elmhurst Av on E
#   Euclid Av (A): avg 25 min, samples=84
#   Euclid Av (C): avg 30 min, samples=55
#   Far Rockaway-Mott Av (A): avg 57 min, samples=34
#   Flatbush Av-Brooklyn College (2): avg 33 min, samples=70
#   Forest Hills-71 Av (E): avg 38 min, samples=74
#   Franklin Av (A): avg 14 min, samples=1
#   Franklin Av (C): avg 14 min, samples=58
#   Franklin Av-Medgar Evers College (2): avg 21 min, samples=73
#   Franklin Av-Medgar Evers College (3): avg 21 min, samples=60
#   Franklin St (1): avg 1 min, samples=107
#   Franklin St (2): avg 1 min, samples=1
#   Freeman St (2): avg 38 min, samples=75
#   Fulton St (2): avg 3 min, samples=77
#   Fulton St (3): avg 3 min, samples=62
#   Fulton St (A): avg 2 min, samples=92
#   Fulton St (C): avg 2 min, samples=60
#   Grand Army Plaza (2): avg 17 min, samples=75
#   Grand Army Plaza (3): avg 17 min, samples=60
#   [INFO] No valid durations for Grand Av-Newtown on E
#   Grant Av (A): avg 27 min, samples=83
#   Gun Hill Rd (2): avg 54 min, samples=69
#   Harlem-148 St (3): avg 28 min, samples=61
#   High St (A): avg 5 min, samples=91
#   High St (C): avg 5 min, samples=60
#   Houston St (1): avg 4 min, samples=106
#   Houston St (2): avg 4 min, samples=1
#   Howard Beach-JFK Airport (A): avg 38 min, samples=42
#   Hoyt St (2): avg 11 min, samples=76
#   Hoyt St (3): avg 11 min, samples=61
#   Hoyt-Schermerhorn Sts (A): avg 9 min, samples=90
#   Hoyt-Schermerhorn Sts (C): avg 9 min, samples=59
#   Intervale Av (2): avg 36 min, samples=75
#   Inwood-207 St (A): avg 37 min, samples=66
#   Jackson Av (2): avg 32 min, samples=77
#   Jackson Hts-Roosevelt Av (E): avg 32 min, samples=75
#   Jamaica Center-Parsons/Archer (E): avg 49 min, samples=66
#   Jamaica-179 St (E): avg 48 min, samples=4
#   Jamaica-Van Wyck (E): avg 45 min, samples=67
#   Jay St-MetroTech (A): avg 7 min, samples=90
#   Jay St-MetroTech (C): avg 7 min, samples=59
#   Junius St (2): avg 36 min, samples=1
#   Junius St (3): avg 34 min, samples=57
#   Kew Gardens-Union Tpke (E): avg 42 min, samples=74
#   Kingston Av (2): avg 25 min, samples=1
#   Kingston Av (3): avg 24 min, samples=58
#   Kingston-Throop Avs (A): avg 16 min, samples=1
#   Kingston-Throop Avs (C): avg 16 min, samples=58
#   Lafayette Av (A): avg 10 min, samples=2
#   Lafayette Av (C): avg 10 min, samples=59
#   Lexington Av/53 St (E): avg 21 min, samples=79
#   Liberty Av (A): avg 24 min, samples=1
#   Liberty Av (C): avg 25 min, samples=56
#   Marble Hill-225 St (1): avg 46 min, samples=87
#   Nereid Av (2): avg 59 min, samples=67
#   Nevins St (2): avg 12 min, samples=76
#   Nevins St (3): avg 12 min, samples=61
#   New Lots Av (2): avg 40 min, samples=1
#   New Lots Av (3): avg 38 min, samples=56
#   Newkirk Av-Little Haiti (2): avg 31 min, samples=70
#   [INFO] No valid durations for Northern Blvd on E
#   Nostrand Av (2): avg 23 min, samples=1
#   Nostrand Av (3): avg 22 min, samples=59
#   Nostrand Av (A): avg 14 min, samples=88
#   Nostrand Av (C): avg 15 min, samples=58
#   Ozone Park-Lefferts Blvd (A): avg 35 min, samples=39
#   Park Place (2): avg 1 min, samples=79
#   Park Place (3): avg 1 min, samples=63
#   Parsons Blvd (E): avg 44 min, samples=4
#   Pelham Pkwy (2): avg 49 min, samples=72
#   Pennsylvania Av (2): avg 37 min, samples=1
#   Pennsylvania Av (3): avg 36 min, samples=56
#   President St-Medgar Evers College (2): avg 24 min, samples=72
#   Prospect Av (2): avg 34 min, samples=76
#   Queens Plaza (E): avg 26 min, samples=78
#   Ralph Av (A): avg 19 min, samples=1
#   Ralph Av (C): avg 20 min, samples=58
#   Rector St (1): avg 2 min, samples=103
#   Rockaway Av (2): avg 34 min, samples=1
#   Rockaway Av (3): avg 33 min, samples=58
#   Rockaway Av (A): avg 21 min, samples=1
#   Rockaway Av (C): avg 22 min, samples=56
#   Rockaway Blvd (A): avg 31 min, samples=82
#   Rockaway Park-Beach 116 St (A): avg 57 min, samples=3
#   Saratoga Av (2): avg 32 min, samples=1
#   Saratoga Av (3): avg 31 min, samples=58
#   [INFO] No valid durations for Shepherd Av on A
#   Shepherd Av (C): avg 29 min, samples=56
#   Simpson St (2): avg 37 min, samples=75
#   South Ferry (1): avg 4 min, samples=102
#   Spring St (A): avg 4 min, samples=2
#   Spring St (C): avg 4 min, samples=61
#   Spring St (E): avg 4 min, samples=84
#   [INFO] No valid durations for Steinway St on E
#   Sterling St (2): avg 25 min, samples=72
#   Sutphin Blvd (E): avg 48 min, samples=66
#   Sutphin Blvd-Archer Av-JFK Airport (E): avg 48 min, samples=66
#   Sutter Av-Rutland Rd (2): avg 30 min, samples=1
#   Sutter Av-Rutland Rd (3): avg 30 min, samples=58
#   Times Sq-42 St (1): avg 13 min, samples=104
#   Times Sq-42 St (2): avg 8 min, samples=85
#   Times Sq-42 St (3): avg 8 min, samples=72
#   Utica Av (A): avg 17 min, samples=87
#   Utica Av (C): avg 18 min, samples=58
#   Van Cortlandt Park-242 St (1): avg 51 min, samples=77
#   Van Siclen Av (2): avg 38 min, samples=1
#   Van Siclen Av (3): avg 37 min, samples=56
#   Van Siclen Av (A): avg 26 min, samples=1
#   Van Siclen Av (C): avg 27 min, samples=56
#   W 4 St-Wash Sq (A): avg 5 min, samples=77
#   W 4 St-Wash Sq (C): avg 5 min, samples=60
#   W 4 St-Wash Sq (E): avg 6 min, samples=84
#   WTC Cortlandt (1): avg 1 min, samples=103
#   Wakefield-241 St (2): avg 61 min, samples=65
#   Wall St (2): avg 4 min, samples=77
#   Wall St (3): avg 4 min, samples=62
#   West Farms Sq-E Tremont Av (2): avg 43 min, samples=73
#   Winthrop St (2): avg 27 min, samples=72
#   [INFO] No valid durations for Woodhaven Blvd on E
#   [INFO] No valid durations for World Trade Center on E
#
# Saved travel_times.json to /Users/isratjahan/travel_times.json
